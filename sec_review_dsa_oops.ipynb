# %% [markdown]
# # **Precision Agriculture Crop Monitoring System**
# ### **TEAM MEMBERS**
# | Name            | Roll Number         |
# |----------------|---------------------|
# | ROAHIYAA T     | CB.SC.U4AIE24043
# |SHIVANANDANA A  | CB.SC.U4AIE24049    |  |
# | SRINITHI K     | CB.SC.U4AIE24055    |
# | VANISHREE S    | CB.SC.U4AIE24059    |
# ### ***OBJECTIVES***
# * Implement AVL Tree for field zone management
# * Track soil moisture, nutrient levels using multi-dimensional arrays
# * Real-time crop type prediction algorithms

# %%
class FieldZone:
    def __init__(self, zone_id, water_level, ph_level, potassium, nitrogen, phosphorus):
        self.zone_id = zone_id
        self._water_level = water_level
        self._ph_level = ph_level
        self._potassium = potassium
        self._nitrogen = nitrogen
        self._phosphorus = phosphorus
        
    def get_water_level(self):
        return self._water_level

    def get_ph_level(self):
        return self._ph_level

    def get_potassium(self):
        return self._potassium

    def get_nitrogen(self):
        return self._nitrogen

    def get_phosphorus(self):
        return self._phosphorus

    def set_water_level(self, new_level):
        if 0 <= new_level <= 100: 
            self._water_level = new_level
        else:
            print("Invalid water level! Must be between 0 and 100.")

    def set_ph_level(self, new_ph):
        if 0 <= new_ph <= 14:  
            self._ph_level = new_ph
        else:
            print("Invalid pH level! Must be between 0 and 14.")

    def set_potassium(self, new_potassium):
        if new_potassium >= 0:
            self._potassium = new_potassium
        else:
            print("Invalid potassium level! Must be non-negative.")

    def set_nitrogen(self, new_nitrogen):
        if new_nitrogen >= 0:
            self._nitrogen = new_nitrogen
        else:
            print("Invalid nitrogen level! Must be non-negative.")

    def set_phosphorus(self, new_phosphorus):
        if new_phosphorus >= 0:
            self._phosphorus = new_phosphorus
        else:
            print("Invalid phosphorus level! Must be non-negative.")

    def __str__(self):
        return f"Zone ID: {self.zone_id}, Water Level: {self.get_water_level()}, pH: {self.get_ph_level()}, K: {self.get_potassium()}, N: {self.get_nitrogen()}, P: {self.get_phosphorus()}"

class Node:
    def __init__(self, field_zone):
        self.field_zone = field_zone
        self.left = None
        self.right = None
        self.height = 1

class AVLTree:
    def __init__(self):
        self.root = None
    
    def insert(self, field_zone):
        self.root = self._insert(self.root, field_zone)
    
    def _insert(self, root, field_zone):
        if not root:
            return Node(field_zone)
        
        if field_zone.zone_id < root.field_zone.zone_id:
            root.left = self._insert(root.left, field_zone)
        else:
            root.right = self._insert(root.right, field_zone)
        
        root.height = 1 + max(self.get_height(root.left), self.get_height(root.right))
        return self._balance(root, field_zone.zone_id)
    
    def _balance(self, root, key):
        balance = self.get_balance(root)
        
        if balance > 1:
            if key < root.left.field_zone.zone_id:
                return self.right_rotate(root)
            else:
                root.left = self.left_rotate(root.left)
                return self.right_rotate(root)
        
        if balance < -1:
            if key > root.right.field_zone.zone_id:
                return self.left_rotate(root)
            else:
                root.right = self.right_rotate(root.right)
                return self.left_rotate(root)
        
        return root
    
    def left_rotate(self, z):
        y = z.right
        z.right = y.left
        y.left = z
        z.height = 1 + max(self.get_height(z.left), self.get_height(z.right))
        y.height = 1 + max(self.get_height(y.left), self.get_height(y.right))
        return y
    
    def right_rotate(self, z):
        y = z.left
        z.left = y.right
        y.right = z
        z.height = 1 + max(self.get_height(z.left), self.get_height(z.right))
        y.height = 1 + max(self.get_height(y.left), self.get_height(y.right))
        return y
    
    def get_height(self, root):
        return root.height if root else 0
    
    def get_balance(self, root):
        return self.get_height(root.left) - self.get_height(root.right) if root else 0
    
    def delete(self, zone_id):
        self.root = self._delete(self.root, zone_id)
    
    def _delete(self, root, zone_id):
        if not root:
            return root
        
        if zone_id < root.field_zone.zone_id:
            root.left = self._delete(root.left, zone_id)
        elif zone_id > root.field_zone.zone_id:
            root.right = self._delete(root.right, zone_id)
        else:
            if not root.left:
                return root.right
            elif not root.right:
                return root.left
            
            temp = self._get_min(root.right)
            root.field_zone = temp.field_zone
            root.right = self._delete(root.right, temp.field_zone.zone_id)
        
        root.height = 1 + max(self.get_height(root.left), self.get_height(root.right))
        return self._balance(root, zone_id)
    
    def _get_min(self, root):
        while root.left:
            root = root.left
        return root

class LinkedListNode:
    def __init__(self, field_zone):
        self.field_zone = field_zone
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def insert(self, field_zone):
        new_node = LinkedListNode(field_zone)
        if not self.head:
            self.head = new_node
        else:
            temp = self.head
            while temp.next:
                temp = temp.next
            temp.next = new_node

    

    def delete(self, zone_id):
         
        temp = self.head
        prev = None
    
        if temp and temp.field_zone.zone_id == zone_id:
             
            self.head = temp.next  
            return 
    
        while temp and temp.field_zone.zone_id != zone_id:
             
            prev = temp
            temp = temp.next
    
        if not temp:
            return
    
        prev.next = temp.next

    def display(self):
        temp = self.head
        while temp:
            print(temp.field_zone)
            temp=temp.next

class FieldZoneManager:
    def __init__(self):
        self.zones = {}
        self.avl_tree = AVLTree()
        self.linked_list = LinkedList()
    
    def add_zone(self, zone_id, water_level, ph_level, potassium, nitrogen, phosphorus):
        field_zone = FieldZone(zone_id, water_level, ph_level, potassium, nitrogen, phosphorus)
        self.zones[zone_id] = field_zone
        self.avl_tree.insert(field_zone)
        self.linked_list.insert(field_zone)
    
    def delete_zone(self, zone_id):
        if zone_id in self.zones:
            del self.zones[zone_id]
            self.avl_tree.delete(zone_id)
            self.linked_list.delete(zone_id) 
    
    def display_zones(self):
        self.linked_list.display()
    
    def check_low_levels(self, water_threshold=30, ph_min=6, ph_max=7.5, nutrient_threshold=20):
        low_zones = [
            zone for zone in self.zones.values()
            if (zone.get_water_level() < water_threshold or
                zone.get_ph_level() < ph_min or
                zone.get_ph_level() > ph_max or
                zone.get_potassium() < nutrient_threshold or
                zone.get_nitrogen() < nutrient_threshold or
                zone.get_phosphorus() < nutrient_threshold)
           ]
        for zone in low_zones:
             print(f"Alert: {zone}")


# Example Usage
data = [
    (1, 50, 6.5, 40, 30, 25),
    (2, 20, 5.8, 15, 10, 18),
    (3, 60, 7.2, 35, 28, 22)
]

zone_manager = FieldZoneManager()
for d in data:
    zone_manager.add_zone(*d)

print("\n=== Field Zones ===")
zone_manager.display_zones()

print("\n=== Low Level Alerts ===")
zone_manager.check_low_levels()
# Out:
# === Field Zones ===
# Zone ID: 1, Water Level: 50, pH: 6.5, K: 40, N: 30, P: 25
# Zone ID: 2, Water Level: 20, pH: 5.8, K: 15, N: 10, P: 18
# Zone ID: 3, Water Level: 60, pH: 7.2, K: 35, N: 28, P: 22
#
# === Low Level Alerts ===
# Alert: Zone ID: 2, Water Level: 20, pH: 5.8, K: 15, N: 10, P: 18

# %%
#soil nutrient tracker
import csv
class FieldZone:
    def __init__(self, crop, nitrogen, phosphorus, potassium, pH, rainfall, temperature):
        self.crop = crop
        self.nitrogen = nitrogen
        self.phosphorus = phosphorus
        self.potassium = potassium
        self.pH = pH
        self.rainfall = rainfall
        self.temperature = temperature

    def display_info(self):
        print(f"Crop: {self.crop} | N: {self.nitrogen} | P: {self.phosphorus} | K: {self.potassium} | pH: {self.pH} | Rainfall: {self.rainfall} | Temperature: {self.temperature}")

class SoilNutrientTracker:
    def __init__(self):
        self.data = []
        self.num_zones = 0
        self.num_parameters = 7  # For nitrogen, phosphorus, potassium, pH, rainfall, temperature

    def load_data(self, file_path):
        try:
            with open(file_path, 'r') as file:
                reader = csv.reader(file)
                next(reader)  # Skip header
                for row in reader:
                    zone = FieldZone(
                        row[1],
                        float(row[2]),
                        float(row[3]),
                        float(row[4]),
                        float(row[5]),
                        float(row[6]),
                        float(row[7]) )
                    self.data.append(zone)
                    self.num_zones += 1
            print("Data loaded successfully!")
        except Exception as e:
            print(f"Error reading file: {e}")

    def update_value(self, zone_index, parameter_index, value):
        if 0 <= zone_index < self.num_zones and 0 <= parameter_index < self.num_parameters:
            zone = self.data[zone_index]
            if parameter_index == 0:
                zone.nitrogen = value
            elif parameter_index == 1:
                zone.phosphorus = value
            elif parameter_index == 2:
                zone.potassium = value
            elif parameter_index == 3:
                zone.pH = value
            elif parameter_index == 4:
                zone.rainfall = value
            elif parameter_index == 5:
                zone.temperature = value
            print(f"Value updated for zone {zone_index}, parameter {parameter_index}.")
        else:
            print("Invalid zone index or parameter index.")

    def get_value(self, zone_index, parameter_index):
        if 0 <= zone_index < self.num_zones and 0 <= parameter_index < self.num_parameters:
            zone = self.data[zone_index]
            if parameter_index == 0:
                return zone.nitrogen
            elif parameter_index == 1:
                return zone.phosphorus
            elif parameter_index == 2:
                return zone.potassium
            elif parameter_index == 3:
                return zone.pH
            elif parameter_index == 4:
                return zone.rainfall
            elif parameter_index == 5:
                return zone.temperature
        else:
            print("Invalid zone index or parameter index.")
            return None

    def trend_analysis(self):
        high_nitrogen_zones = [zone for zone in self.data if zone.nitrogen > 100]
        optimal_pH_zones = [zone for zone in self.data if 6.0 <= zone.pH <= 7.5]
        
        print("Trend Analysis:")
        print(f"Zones with high nitrogen (>100): {len(high_nitrogen_zones)}")
        print(f"Zones with optimal pH (6.0-7.5): {len(optimal_pH_zones)}")

    def generate_report(self):
        high_nitrogen_zones = [zone for zone in self.data if zone.nitrogen > 100]
        optimal_pH_zones = [zone for zone in self.data if 6.0 <= zone.pH <= 7.5]

        print("\nSoil Nutrient Report:")
        print(f"Total number of zones: {self.num_zones}")
        print(f"Zones with high nitrogen (>100): {len(high_nitrogen_zones)}")
        print(f"Zones with optimal pH (6.0-7.5): {len(optimal_pH_zones)}")
        print("Actionable Insights:")
        print("1. Consider reducing nitrogen levels in high nitrogen zones.")
        print("2. Zones with optimal pH levels are ideal for a variety of crops.")

    def display_data(self):
        for zone in self.data:
            zone.display_info()

if __name__ == "__main__":
    tracker = SoilNutrientTracker()
    tracker.load_data(r"C:\Users\Shivananda\Downloads\Train Dataset.csv")
    tracker.display_data()
    tracker.trend_analysis()
    tracker.generate_report()
    # Example of updating a value
    tracker.update_value(0, 0, 120)  # Update nitrogen value of the first zone to 120
    print(f"Updated Nitrogen Value: {tracker.get_value(0, 0)}")
# Out:
# Data loaded successfully!
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.54 | Rainfall: 75.32 | Temperature: 22.676
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.54 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.02 | Rainfall: 689.88 | Temperature: 29.03727273
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.66 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.38 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.52 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.08 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 4.84 | Rainfall: 1050.245 | Temperature: 18.77818182
# Crop: jute | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.5 | Rainfall: 1166.94 | Temperature: 28.33333333
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.52 | Rainfall: 182.5 | Temperature: 29.2
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.0 | Rainfall: 1426.3 | Temperature: 26.73636364
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.1 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 1543.76 | Temperature: 27.33333333
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 98.98 | Temperature: 34.92333333
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.56 | Rainfall: 1220.22 | Temperature: 27.26666667
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.14 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.1 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.94 | Rainfall: 98.94 | Temperature: 25.574
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 207.55 | Temperature: 26.43333333
# Crop: cabbage | N: 100.0 | P: 65.0 | K: 70.0 | pH: 6.62 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.5 | Rainfall: 169.82 | Temperature: 14.6
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.58 | Rainfall: 810.26 | Temperature: 29.95636364
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.48 | Rainfall: 1997.12 | Temperature: 27.0
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.52 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.4 | Rainfall: 73.47 | Temperature: 23.562
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.64 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.34 | Rainfall: 288.3 | Temperature: 25.46
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.14 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.46 | Rainfall: 70.598 | Temperature: 18.92
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.98 | Rainfall: 73.47 | Temperature: 23.562
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.36 | Rainfall: 884.5 | Temperature: 27.65454545
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.16 | Rainfall: 75.32 | Temperature: 22.676
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 87.2 | Temperature: 23.106
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.36 | Rainfall: 127.68 | Temperature: 20.8
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.14 | Rainfall: 810.26 | Temperature: 29.95636364
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.5 | Rainfall: 1712.66 | Temperature: 11.2
# Crop: jute | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.52 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.58 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.06 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 4.92 | Rainfall: 1501.98 | Temperature: 25.81818182
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.4 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.6 | Rainfall: 1350.025 | Temperature: 26.01818182
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.46 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.38 | Rainfall: 140.52 | Temperature: 12.5
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 579.75 | Temperature: 34.01
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 423.745 | Temperature: 22.07
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.86 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.68 | Rainfall: 556.2 | Temperature: 28.54545455
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.9 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: mango | N: 20.0 | P: 20.0 | K: 30.0 | pH: 5.18 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.44 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.56 | Rainfall: 75.32 | Temperature: 22.676
# Crop: tomato | N: 100.0 | P: 40.0 | K: 90.0 | pH: 6.02 | Rainfall: 714.68 | Temperature: 26.45454545
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 702.459 | Temperature: 27.23333333
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 579.75 | Temperature: 34.01
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.54 | Rainfall: 288.3 | Temperature: 25.46
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.68 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.94 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.66 | Rainfall: 579.75 | Temperature: 34.01
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.5 | Rainfall: 75.32 | Temperature: 22.676
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.34 | Rainfall: 162.72 | Temperature: 29.4
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 167.38 | Temperature: 23.56
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.16 | Rainfall: 75.32 | Temperature: 22.676
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.1 | Rainfall: 288.3 | Temperature: 25.46
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.86 | Rainfall: 122.42 | Temperature: 18.58
# Crop: brinjal | N: 80.0 | P: 15.0 | K: 40.0 | pH: 6.48 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.46 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.54 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.66 | Rainfall: 556.2 | Temperature: 28.54545455
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.4 | Rainfall: 240.1 | Temperature: 10.38
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.56 | Rainfall: 288.3 | Temperature: 25.46
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.36 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.6 | Rainfall: 70.598 | Temperature: 18.92
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.4 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.92 | Rainfall: 75.32 | Temperature: 22.676
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.38 | Rainfall: 942.8 | Temperature: 28.99454545
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.12 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.06 | Rainfall: 1426.3 | Temperature: 26.73636364
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.88 | Rainfall: 240.1 | Temperature: 10.38
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.34 | Rainfall: 556.2 | Temperature: 28.54545455
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.3 | Rainfall: 15.34 | Temperature: 27.276
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.12 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.94 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.9 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: jute | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.54 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.12 | Rainfall: 1151.02 | Temperature: 28.03333333
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.02 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.18 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: blackgram | N: 40.0 | P: 60.0 | K: 20.0 | pH: 4.96 | Rainfall: 127.68 | Temperature: 20.8
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.44 | Rainfall: 942.8 | Temperature: 28.99454545
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 579.75 | Temperature: 34.01
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.84 | Rainfall: 127.68 | Temperature: 20.8
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.36 | Rainfall: 157.31 | Temperature: 25.83333333
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.52 | Rainfall: 810.26 | Temperature: 29.95636364
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.36 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: brinjal | N: 80.0 | P: 15.0 | K: 40.0 | pH: 6.44 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.3 | Rainfall: 122.42 | Temperature: 18.58
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 790.98 | Temperature: 30.61666667
# Crop: cardamom | N: 75.0 | P: 75.0 | K: 150.0 | pH: 4.84 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.36 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.5 | Rainfall: 810.26 | Temperature: 29.95636364
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.82 | Rainfall: 556.2 | Temperature: 28.54545455
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.42 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 182.5 | Temperature: 29.2
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.34 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.11 | Rainfall: 73.47 | Temperature: 23.562
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.36 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.46 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.84 | Rainfall: 689.88 | Temperature: 29.03727273
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.36 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.66 | Rainfall: 152.54 | Temperature: 22.28
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.06 | Rainfall: 75.32 | Temperature: 22.676
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.58 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.04 | Rainfall: 113.7 | Temperature: 30.26666667
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.34 | Rainfall: 152.54 | Temperature: 22.28
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 87.2 | Temperature: 23.106
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.04 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: jute | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 1166.94 | Temperature: 28.33333333
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.04 | Rainfall: 240.1 | Temperature: 10.38
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.66 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.44 | Rainfall: 331.88 | Temperature: 35.34666667
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 40.023 | Temperature: 23.14
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.18 | Rainfall: 942.8 | Temperature: 28.99454545
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.9 | Rainfall: 167.38 | Temperature: 23.56
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.54 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 4.98 | Rainfall: 579.75 | Temperature: 34.01
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.66 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.46 | Rainfall: 411.52 | Temperature: 34.73
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.66 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 56.236 | Temperature: 15.852
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.68 | Rainfall: 235.4251 | Temperature: 26.64666667
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.6 | Rainfall: 288.3 | Temperature: 25.46
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 87.2 | Temperature: 23.106
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.44 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.54 | Rainfall: 1151.02 | Temperature: 28.03333333
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.12 | Rainfall: 152.54 | Temperature: 22.28
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.56 | Rainfall: 73.47 | Temperature: 23.562
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.34 | Rainfall: 331.88 | Temperature: 35.34666667
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.36 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.08 | Rainfall: 41.3 | Temperature: 21.704
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.88 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: blackpepper | N: 100.0 | P: 60.0 | K: 50.0 | pH: 5.18 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: mango | N: 20.0 | P: 20.0 | K: 30.0 | pH: 5.08 | Rainfall: 714.68 | Temperature: 26.45454545
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.02 | Rainfall: 75.32 | Temperature: 22.676
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.36 | Rainfall: 240.1 | Temperature: 10.38
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.06 | Rainfall: 87.2 | Temperature: 23.106
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.32 | Rainfall: 1299.26 | Temperature: 26.51818182
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.58 | Rainfall: 1151.02 | Temperature: 28.03333333
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.46 | Rainfall: 1110.78 | Temperature: 25.66666667
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 70.598 | Temperature: 18.92
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.0 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.98 | Rainfall: 167.38 | Temperature: 23.56
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.6 | Rainfall: 167.38 | Temperature: 23.56
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 98.98 | Temperature: 34.92333333
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 4.96 | Rainfall: 579.75 | Temperature: 34.01
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.96 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.58 | Rainfall: 579.75 | Temperature: 34.01
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.54 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: orange | N: 20.0 | P: 10.0 | K: 10.0 | pH: 4.04 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 127.68 | Temperature: 20.8
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.98 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.06 | Rainfall: 1299.26 | Temperature: 26.51818182
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.38 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.34 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.58 | Rainfall: 152.54 | Temperature: 22.28
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 664.94 | Temperature: 22.03333333
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.1 | Rainfall: 94.02 | Temperature: 22.38
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 157.31 | Temperature: 25.83333333
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.3 | Rainfall: 293.36 | Temperature: 14.7
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 70.11 | Temperature: 25.6
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.36 | Rainfall: 122.42 | Temperature: 18.58
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.48 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.5 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.56 | Rainfall: 75.32 | Temperature: 22.676
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 4.84 | Rainfall: 1426.3 | Temperature: 26.73636364
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 288.3 | Temperature: 25.46
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.02 | Rainfall: 75.32 | Temperature: 22.676
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.11 | Rainfall: 122.42 | Temperature: 18.58
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 1166.94 | Temperature: 28.33333333
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.02 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.06 | Rainfall: 75.32 | Temperature: 22.676
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.96 | Rainfall: 94.02 | Temperature: 22.38
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.64 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.38 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.88 | Rainfall: 1110.78 | Temperature: 25.66666667
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.1 | Rainfall: 207.55 | Temperature: 26.43333333
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.38 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.94 | Rainfall: 75.32 | Temperature: 22.676
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.92 | Rainfall: 556.2 | Temperature: 28.54545455
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 131.18 | Temperature: 23.13333333
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.58 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.06 | Rainfall: 1299.26 | Temperature: 26.51818182
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.14 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.42 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.32 | Rainfall: 770.44 | Temperature: 28.68
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.94 | Rainfall: 87.2 | Temperature: 23.106
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 4.96 | Rainfall: 579.75 | Temperature: 34.01
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.32 | Rainfall: 1299.26 | Temperature: 26.51818182
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.56 | Rainfall: 1110.78 | Temperature: 25.66666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.9 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.44 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.82 | Rainfall: 157.31 | Temperature: 25.83333333
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.56 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.42 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.3 | Rainfall: 15.34 | Temperature: 27.276
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.4 | Rainfall: 75.32 | Temperature: 22.676
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.96 | Rainfall: 75.32 | Temperature: 22.676
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.54 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.58 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.96 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.16 | Rainfall: 579.75 | Temperature: 34.01
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.6 | Rainfall: 94.02 | Temperature: 22.38
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.86 | Rainfall: 689.88 | Temperature: 29.03727273
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.5 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: jute | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.32 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 884.5 | Temperature: 27.65454545
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.66 | Rainfall: 157.31 | Temperature: 25.83333333
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.56 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.9 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.58 | Rainfall: 664.94 | Temperature: 22.03333333
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.44 | Rainfall: 37.09 | Temperature: 27.96666667
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.14 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.02 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: tomato | N: 100.0 | P: 40.0 | K: 90.0 | pH: 6.02 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.6 | Rainfall: 330.0 | Temperature: 29.33333333
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.66 | Rainfall: 1997.12 | Temperature: 27.0
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.42 | Rainfall: 75.32 | Temperature: 22.676
# Crop: grapes | N: 20.0 | P: 125.0 | K: 200.0 | pH: 4.04 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 1875.6 | Temperature: 20.1
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.58 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.8 | Rainfall: 19.38 | Temperature: 22.766
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.42 | Rainfall: 98.98 | Temperature: 34.92333333
# Crop: ladyfinger | N: 80.0 | P: 10.0 | K: 40.0 | pH: 6.62 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.84 | Rainfall: 152.54 | Temperature: 22.28
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.58 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.46 | Rainfall: 70.11 | Temperature: 25.6
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.5 | Rainfall: 152.54 | Temperature: 22.28
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.34 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.34 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.52 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 98.98 | Temperature: 34.92333333
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 331.88 | Temperature: 35.34666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.58 | Rainfall: 579.75 | Temperature: 34.01
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 579.75 | Temperature: 34.01
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.5 | Rainfall: 1011.49 | Temperature: 30.43
# ...
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.32 | Rainfall: 66.52 | Temperature: 20.312
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.58 | Rainfall: 1037.32 | Temperature: 28.08181818
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.46 | Rainfall: 579.75 | Temperature: 34.01
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.6 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.14 | Rainfall: 288.3 | Temperature: 25.46
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.46 | Rainfall: 98.98 | Temperature: 34.92333333
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.44 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.04 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.42 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.48 | Rainfall: 113.7 | Temperature: 30.26666667
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.58 | Rainfall: 288.3 | Temperature: 25.46
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.82 | Rainfall: 1411.78 | Temperature: 19.94545455
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 73.47 | Temperature: 23.562
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.84 | Rainfall: 689.88 | Temperature: 29.03727273
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.48 | Rainfall: 87.2 | Temperature: 23.106
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.06 | Rainfall: 19.38 | Temperature: 22.766
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 87.2 | Temperature: 23.106
# Crop: tomato | N: 100.0 | P: 40.0 | K: 90.0 | pH: 5.94 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.66 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.96 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.36 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 4.84 | Rainfall: 2817.86 | Temperature: 27.90909091
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.18 | Rainfall: 884.5 | Temperature: 27.65454545
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.36 | Rainfall: 1712.66 | Temperature: 11.2
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 9.627044 | Temperature: 16.82
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.38 | Rainfall: 87.2 | Temperature: 23.106
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.36 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.4 | Rainfall: 1110.78 | Temperature: 25.66666667
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.48 | Rainfall: 152.54 | Temperature: 22.28
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 85.24316 | Temperature: 21.482
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 127.68 | Temperature: 20.8
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.54 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.18 | Rainfall: 1145.22 | Temperature: 28.5
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.6 | Rainfall: 1712.66 | Temperature: 11.2
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 411.52 | Temperature: 34.73
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.56 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.58 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.66 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.08 | Rainfall: 98.94 | Temperature: 25.574
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.02 | Rainfall: 1037.32 | Temperature: 28.08181818
# Crop: coriander | N: 10.0 | P: 20.0 | K: 20.0 | pH: 6.46 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.4 | Rainfall: 1151.02 | Temperature: 28.03333333
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.52 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.1 | Rainfall: 1411.78 | Temperature: 19.94545455
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.0 | Rainfall: 127.68 | Temperature: 20.8
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.4 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.06 | Rainfall: 75.32 | Temperature: 22.676
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.46 | Rainfall: 87.2 | Temperature: 23.106
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 702.459 | Temperature: 27.23333333
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.5 | Rainfall: 207.55 | Temperature: 26.43333333
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.42 | Rainfall: 1151.02 | Temperature: 28.03333333
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.92 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.9 | Rainfall: 75.32 | Temperature: 22.676
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 4.94 | Rainfall: 2817.86 | Temperature: 27.90909091
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.42 | Rainfall: 1166.94 | Temperature: 28.33333333
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.11 | Rainfall: 70.598 | Temperature: 18.92
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.58 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.32 | Rainfall: 579.75 | Temperature: 34.01
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.82 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 87.2 | Temperature: 23.106
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.06 | Rainfall: 87.2 | Temperature: 23.106
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 167.38 | Temperature: 23.56
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 1220.22 | Temperature: 27.26666667
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.52 | Rainfall: 702.459 | Temperature: 27.23333333
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.9 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.52 | Rainfall: 790.98 | Temperature: 30.61666667
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.82 | Rainfall: 884.5 | Temperature: 27.65454545
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.56 | Rainfall: 157.31 | Temperature: 25.83333333
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.44 | Rainfall: 98.94 | Temperature: 25.574
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.44 | Rainfall: 331.88 | Temperature: 35.34666667
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 579.75 | Temperature: 34.01
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.0 | Rainfall: 2169.32 | Temperature: 23.73636364
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 75.32 | Temperature: 22.676
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.56 | Rainfall: 288.3 | Temperature: 25.46
# Crop: brinjal | N: 80.0 | P: 15.0 | K: 40.0 | pH: 6.44 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: jute | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.38 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: horsegram | N: 20.0 | P: 60.0 | K: 20.0 | pH: 6.04 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.08 | Rainfall: 85.24316 | Temperature: 21.482
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.58 | Rainfall: 579.75 | Temperature: 34.01
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.5 | Rainfall: 73.47 | Temperature: 23.562
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.0 | Rainfall: 122.42 | Temperature: 18.58
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.46 | Rainfall: 113.7 | Temperature: 30.26666667
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.84 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.88 | Rainfall: 884.5 | Temperature: 27.65454545
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.1 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: sunflower | N: 50.0 | P: 60.0 | K: 30.0 | pH: 5.52 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.34 | Rainfall: 87.2 | Temperature: 23.106
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.92 | Rainfall: 152.54 | Temperature: 22.28
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.4 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.62 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.12 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.52 | Rainfall: 19.38 | Temperature: 22.766
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 235.4251 | Temperature: 26.64666667
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.66 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.56 | Rainfall: 579.75 | Temperature: 34.01
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.64 | Rainfall: 770.44 | Temperature: 28.68
# Crop: cotton | N: 120.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 510.05 | Temperature: 33.37333333
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.4 | Rainfall: 241.78 | Temperature: 1.18
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.1 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.0 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.12 | Rainfall: 810.26 | Temperature: 29.95636364
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 5.18 | Rainfall: 689.88 | Temperature: 29.03727273
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 162.72 | Temperature: 29.4
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.56 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.6 | Rainfall: 579.75 | Temperature: 34.01
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.58 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.68 | Rainfall: 516.68 | Temperature: 27.86666667
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.44 | Rainfall: 235.4251 | Temperature: 26.64666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.34 | Rainfall: 579.75 | Temperature: 34.01
# Crop: blackpepper | N: 100.0 | P: 60.0 | K: 50.0 | pH: 4.88 | Rainfall: 1050.245 | Temperature: 18.77818182
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.96 | Rainfall: 157.31 | Temperature: 25.83333333
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.96 | Rainfall: 87.2 | Temperature: 23.106
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.34 | Rainfall: 87.2 | Temperature: 23.106
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 15.34 | Temperature: 27.276
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.34 | Rainfall: 75.32 | Temperature: 22.676
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.5 | Rainfall: 113.7 | Temperature: 30.26666667
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 199.2125 | Temperature: 21.3
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 4.9 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: tomato | N: 100.0 | P: 40.0 | K: 90.0 | pH: 6.02 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.9 | Rainfall: 15.34 | Temperature: 27.276
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.68 | Rainfall: 297.66 | Temperature: 29.56666667
# Crop: cardamom | N: 75.0 | P: 75.0 | K: 150.0 | pH: 4.88 | Rainfall: 2817.86 | Temperature: 27.90909091
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 4.84 | Rainfall: 169.82 | Temperature: 14.6
# Crop: rapeseed | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.04 | Rainfall: 75.32 | Temperature: 22.676
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.18 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.5 | Rainfall: 1246.715 | Temperature: 22.6
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.38 | Rainfall: 1166.94 | Temperature: 28.33333333
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 654.34 | Temperature: 29.26666667
# Crop: sweetpotato | N: 90.0 | P: 20.0 | K: 120.0 | pH: 5.16 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.54 | Rainfall: 73.47 | Temperature: 23.562
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.8 | Rainfall: 19.38 | Temperature: 22.766
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.52 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.4 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: soyabean | N: 20.0 | P: 60.0 | K: 20.0 | pH: 5.58 | Rainfall: 1151.02 | Temperature: 28.03333333
# Crop: potato | N: 180.0 | P: 60.0 | K: 90.0 | pH: 4.92 | Rainfall: 689.88 | Temperature: 29.03727273
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: barley | N: 70.0 | P: 40.0 | K: 45.0 | pH: 5.64 | Rainfall: 73.47 | Temperature: 23.562
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 6.04 | Rainfall: 75.32 | Temperature: 22.676
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.44 | Rainfall: 75.32 | Temperature: 22.676
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.52 | Rainfall: 840.46 | Temperature: 33.58333333
# Crop: moong | N: 20.0 | P: 40.0 | K: 20.0 | pH: 5.56 | Rainfall: 73.47 | Temperature: 23.562
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.58 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: maize | N: 80.0 | P: 40.0 | K: 20.0 | pH: 5.62 | Rainfall: 579.75 | Temperature: 34.01
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.5 | Rainfall: 1011.49 | Temperature: 30.43
# Crop: wheat | N: 60.0 | P: 30.0 | K: 30.0 | pH: 6.8 | Rainfall: 70.11 | Temperature: 25.6
# Crop: rice | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.64 | Rainfall: 34.81 | Temperature: 34.66666667
# Crop: garlic | N: 50.0 | P: 10.0 | K: 60.0 | pH: 5.36 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: ragi | N: 50.0 | P: 40.0 | K: 20.0 | pH: 5.6 | Rainfall: 607.48 | Temperature: 26.36666667
# Crop: banana | N: 100.0 | P: 75.0 | K: 50.0 | pH: 6.56 | Rainfall: 1603.2375 | Temperature: 22.89090909
# Crop: onion | N: 120.0 | P: 60.0 | K: 65.0 | pH: 5.82 | Rainfall: 1026.64 | Temperature: 29.18636364
# Crop: mango | N: 20.0 | P: 20.0 | K: 30.0 | pH: 5.16 | Rainfall: 884.5 | Temperature: 27.65454545
# Crop: jowar | N: 80.0 | P: 40.0 | K: 40.0 | pH: 5.44 | Rainfall: 770.44 | Temperature: 28.68
# Crop: papaya | N: 50.0 | P: 50.0 | K: 50.0 | pH: 5.94 | Rainfall: 1111.68 | Temperature: 28.64818182
# Crop: turmeric | N: 25.0 | P: 60.0 | K: 100.0 | pH: 5.06 | Rainfall: 556.2 | Temperature: 28.54545455
# Trend Analysis:
# Zones with high nitrogen (>100): 2769
# Zones with optimal pH (6.0-7.5): 3438
#
# Soil Nutrient Report:
# Total number of zones: 18079
# Zones with high nitrogen (>100): 2769
# Zones with optimal pH (6.0-7.5): 3438
# Actionable Insights:
# 1. Consider reducing nitrogen levels in high nitrogen zones.
# 2. Zones with optimal pH levels are ideal for a variety of crops.
# Value updated for zone 0, parameter 0.
# Updated Nitrogen Value: 120
